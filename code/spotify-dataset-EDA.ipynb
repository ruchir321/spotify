# %% [markdown]
# # First notebook
# ## Objective
# Genre analysis and Artist Impact Analysis
# <!-- Just do EDA, find what EDA involves. Go ham 💪 -->
#
# ## Dataset
# https://www.kaggle.com/datasets/nelgiriyewithana/top-spotify-songs-2023

# %% [markdown]
# ## Code Blocks

# %% [markdown]
# ### 1. Import EDA libraries
# - pandas: df ftw
# - matplotlib.pyplot: cuz I'm a noob
# - scikitlearn.< idk >: training wheels on
# - ...?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Read dataset into dataframe
# <!-- I cheated (a little bit): https://www.kaggle.com/code/mertbayraktar/eda-freq-collab-artists -->

# %%
# what's ISO-8859-1 (fancy!)
df = pd.read_csv(r"C:\Users\ruchi\OneDrive - UBC\Ruchir\git\kaggle\spotify\data\spotify-2023.csv",encoding='ISO-8859-1')

# %%
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %% [markdown]
# ### 3. Look at the super basic stuff
#
# - Descriptive stats: mean, median, min, max
# - Determine the distribution of categorical features
# - functions: head, tail, describe, column, \<any other ad-hoc function\>
#
# **NOTE:** describe() provides all descreptive stats for numerical features. \(good way to look at num features\)

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %% [markdown]
# #### 3.1 Split the cat and num columns?
# Try

# %%
# list the columns' dtypes
dtypes_series = df.dtypes

# type(df.dtypes)

# %%
df_numerical_columns = df.select_dtypes(include=['int64','float64'])
df_categorical_columns = df.select_dtypes(include='object')

# %%
df.dtypes
# Out:
# track_name               object
# artist(s)_name           object
# artist_count              int64
# released_year             int64
# released_month            int64
# released_day              int64
# in_spotify_playlists      int64
# in_spotify_charts         int64
# streams                 float64
# in_apple_playlists        int64
# in_apple_charts           int64
# in_deezer_playlists      object
# in_deezer_charts          int64
# in_shazam_charts         object
# bpm                       int64
# key                      object
# mode                     object
# danceability_%            int64
# valence_%                 int64
# energy_%                  int64
# acousticness_%            int64
# instrumentalness_%        int64
# liveness_%                int64
# speechiness_%             int64
# dtype: object

# %%
len(df_numerical_columns.columns)
# Out:
# 18

# %%
len(df_categorical_columns.columns)
# Out:
# 6

# %%
df_categorical_columns.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'in_deezer_playlists',
#        'in_shazam_charts', 'key', 'mode'],
#       dtype='object')

# %%
df_numerical_columns.columns
# Out:
# Index(['artist_count', 'released_year', 'released_month', 'released_day',
#        'in_spotify_playlists', 'in_spotify_charts', 'streams',
#        'in_apple_playlists', 'in_apple_charts', 'in_deezer_charts', 'bpm',
#        'danceability_%', 'valence_%', 'energy_%', 'acousticness_%',
#        'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %% [markdown]
# #### 3.2 Drill down on the cat cols
# - Frequency

# %%
df_categorical_columns
# Out:
#                               track_name      artist(s)_name    streams  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook  141381703
# 1                                   LALA         Myke Towers  133716286
# 2                                vampire      Olivia Rodrigo  140003974
# 3                           Cruel Summer        Taylor Swift  800840817
# 4                         WHERE SHE GOES           Bad Bunny  303236322
# ..                                   ...                 ...        ...
# 948                         My Mind & Me        Selena Gomez   91473363
# 949            Bigger Than The Whole Sky        Taylor Swift  121871870
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra   73513683
# 951                        En La De Ella  Feid, Sech, Jhayco  133895612
# 952                                Alone           Burna Boy   96007391
#
#     in_deezer_playlists in_shazam_charts key   mode
# ...

# %%
counts = df_categorical_columns.value_counts(['artist(s)_name'])
df_counts = pd.DataFrame(counts)

df_counts.plot(kind='bar',xticks=[])
# plt.axis('off')
plt.show()

# %%
df_categorical_columns['streams'].describe()
# Out:
# count           953
# unique          949
# top       723894473
# freq              2
# Name: streams, dtype: object

# %% [markdown]
# ### 4. Move 'streams' column to numeric column df
# It's with cat columns cuz the dtyp is object
#  - Convert object to int64: to_numeric
#  - Split the columns again

# %%
# df['streams'] = pd.to_numeric(df['streams'],errors='coerce',downcast='integer')
df['streams'] = df['streams'].astype('int64', errors='ignore')

# %%
df['streams']
# Out:
# 0      141381703.0
# 1      133716286.0
# 2      140003974.0
# 3      800840817.0
# 4      303236322.0
#           ...
# 948     91473363.0
# 949    121871870.0
# 950     73513683.0
# 951    133895612.0
# 952     96007391.0
# Name: streams, Length: 953, dtype: float64

# %% [markdown]
# **note to self:** Use pandas-profiling later

# %% [markdown]
# ### 5. Ask quick questions
# Correlation?

# %% [markdown]
# **Which artist makes you dance the most?**

# %%
df.groupby('artist(s)_name')[['danceability_%']].mean().sort_values(['danceability_%'],ascending=False).head(20)
# Out:
#                                                     danceability_%
# artist(s)_name
# Ed Sheeran, Fireboy DML                                       96.0
# Karol G, Ovy On The Drums                                     95.0
# Coi Leray                                                     95.0
# Dave                                                          95.0
# L7nnon, DJ Biel do Furduncinho, Bianca                        95.0
# NLE Choppa                                                    94.0
# Cartel De Santa, La Kelly                                     93.0
# Mc Pedrinho, DJ 900                                           93.0
# Luï¿½ï¿½sa Sonza, MC Frog, Dj Gabriel do Borel,...            93.0
# Eminem, Dr. Dre                                               92.5
# Dave, Central Cee                                             92.0
# Kendrick Lamar, Kodak Black                                   92.0
# Baby Tate                                                     92.0
# ...

# %% [markdown]
# **Who's the buzzkill?**
# Least danceable
# Rihanna lol

# %%
df.groupby('artist(s)_name')[['danceability_%']].mean().sort_values(['danceability_%'],ascending=False).tail(20)
# Out:
#                                                     danceability_%
# artist(s)_name
# James Arthur                                                  37.0
# Labrinth, Zendaya                                             37.0
# Benson Boone                                                  36.0
# Dove Cameron                                                  35.0
# The Killers                                                   35.0
# Billie Eilish, Khalid                                         35.0
# Surf Curse                                                    35.0
# Darlene Love                                                  34.0
# Mariah Carey                                                  34.0
# Stephen Sanchez                                               34.0
# Em Beihold, Stephen Sanchez                                   34.0
# John Legend, Metro Boomin                                     33.0
# John Lennon, The Harlem Community Choir, The Pl...            33.0
# ...

# %% [markdown]
# Dayum, I thought popular artist would be more danceable.
# Whats the correlation b/w danceability and following
